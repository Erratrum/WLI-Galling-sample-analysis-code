# %%
## Main Script

# Run all other files from here is possible.
start_time = time.time()

# %%
#------------#------------#
# Get them Libraries
#------------#------------#

import numpy as np
import pandas as pd
import os
import sys
import time

import matplotlib as mpl

import h5py

#------------#------------#
# Font Settings
#------------#------------#

# Set global font to Times New Roman and font size to 10pt
mpl.rcParams['font.family'] = 'Times New Roman'
mpl.rcParams['font.size'] = 10
plot_font_size = 20

# %%
# Name the file you care about

# Folder Name
xyz_folder_name = "C - TWIP980"

# File Names
sample_name = 'C7 Post-Galling Test.xyz'

# Did it gall? - for quantification threshold change
did_it_gall = False

# %%
#------------#------------#
# Run Sub Files
#------------#------------#

## Works only if the python files are all in the same folder/level due to the reliance on 'os.getcwd()' in sub-files whcih is nessisary for Jupyter
## If using Jupyter ipython files, can't use 'import' to use files.
## If using normal .py files '%run' won't work, use 'import'. Will need to change the %run in each sub-file too.

def run_Data_Processing(xyz_folder_name, sample_name):
    # %run Data_Processing.ipynb {xyz_folder_name, sample_name}

def run_Surface_Quantification(xyz_folder_name, sample_name):
    # %run Surface_Quantification.ipynb {xyz_folder_name, sample_name}

def run_2D_Visualisation(xyz_folder_name, sample_name):
    # %run 2D_Visualisation.ipynb {xyz_folder_name, sample_name}

def run_3D_Visualisation(xyz_folder_name, sample_name):
    # %run 3D_Visualisation.ipynb {xyz_folder_name, sample_name} 
    ### WARNING IT TAKES FOR EVERRR TO RUN ###






# Suppress output ## WHy isnt it working????
with open(os.devnull, 'w') as fnull:
    sys.stdout = fnull
    
    #run_Data_Processing(xyz_folder_name, sample_name)
    #run_Surface_Quantification(xyz_folder_name, sample_name)
    run_2D_Visualisation(xyz_folder_name, sample_name)
    #run_3D_

    sys.stdout = sys.__stdout__  # Restore stdout
    

end_time = time.time()
print('Time elapsed: ', end_time - start_time, ' seconds')

# %%
#------------#------------#
# For all the files in a given folder
#------------#------------#

## DANGER THIS COULD TAKE A WHILE ##


print('Currently running file ', )

    for i in range(sample_names.shape):
        print(i, ': ', sample_name[i])
        
        # Suppress output
        with open(os.devnull, 'w') as fnull:
            sys.stdout = fnull
            
            #run_Data_Processing(xyz_folder_name, sample_name[i])
            run_Surface_Quantification(xyz_folder_name, sample_name[i])
            #run_2D_Visualisation(xyz_folder_name, sample_name[i])
        
            sys.stdout = sys.__stdout__  # Restore stdout
